# %%
import pandas as pd
import json

# %%
df = pd.read_csv('data/survey_response.csv')
df
# Out:
#               Timestamp  Score                      Full Name  \
# 0                   NaN    NaN                            NaN
# 1   10/11/2022 13:24:29    NaN                      Joy Huang
# 2   10/11/2022 13:33:53    NaN                    Yichen Zhao
# 3   10/11/2022 13:37:21    NaN                    Johnny Chau
# 4   10/11/2022 13:57:09    NaN                       Ben Chen
# 5   10/11/2022 14:06:19    NaN                 Matt Marwedel
# 6   10/11/2022 14:07:47    NaN                    Tzu An Wang
# 7   10/11/2022 14:07:49    NaN                         Max Ma
# 8   10/11/2022 14:08:29    NaN                   Deepak Singh
# 9   10/11/2022 14:13:54    NaN                 Vichitra Kumar
# 10  10/11/2022 14:15:52    NaN                  Joren Libunao
# 11  10/11/2022 14:18:21    NaN                      Shan Wang
# 12  10/11/2022 14:19:21    NaN                 Javier Pacheco
# 13  10/11/2022 14:21:39    NaN           Prithvi Nuthanakalva
# ...

# %%
df.drop(columns=['Score', 'Timestamp'], axis=0, inplace=True)
df = df[1:]
df = df.reset_index()
df.drop(columns=['index'], inplace=True)
df
# Out:
#                         Full Name Where is your hometown? (City, Country)  \
# 0                       Joy Huang                           Xiamen, China
# 1                     Yichen Zhao                         Shanghai, China
# 2                     Johnny Chau                               Hong Kong
# 3                        Ben Chen                                  Taiwan
# 4                  Matt Marwedel                                Iowa, USA
# 5                     Tzu An Wang                         Taoyuan, Taiwan
# 6                          Max Ma                            Linyi, China
# 7                    Deepak Singh                         Gurugram, India
# 8                  Vichitra Kumar                            Delhi, India
# 9                   Joren Libunao                        Los Angeles, USA
# 10                      Shan Wang                      Qinhuangdao, China
# 11                 Javier Pacheco                         Sacramento, USA
# ...

# %%
df['Please rank 5 of your favorite dishes.'][10]
# Out:
# 'Spicy Hotpot; steak; dumplings; pasta; Korean bbq; '

# %%
df['Full Name'][5] = 'Tzu-An Wang'
df['Full Name'][23] = 'Patricia Jauregu'
df['Full Name'][26] = 'Lingraj Vannur'
df['Full Name'][28] = 'Andres Martinez-Tobon'
df['Full Name'][30] = 'Tejaswi Dasari'
df['Full Name'][33] = 'Camilo Chaves'
df['Full Name'][35] = 'Yu-Hsin Wang'
df['Please rank 5 of your favorite dishes.'][10] = 'Spicy Hotpot, steak, dumplings, pasta, Korean bbq'
# Out:
# /var/folders/hj/tfwdfqxx77qf5hd3j44tmf2c0000gn/T/ipykernel_32054/2205493449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Full Name'][5] = 'Tzu-An Wang'
# /var/folders/hj/tfwdfqxx77qf5hd3j44tmf2c0000gn/T/ipykernel_32054/2205493449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Full Name'][23] = 'Patricia Jauregu'
# /var/folders/hj/tfwdfqxx77qf5hd3j44tmf2c0000gn/T/ipykernel_32054/2205493449.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#                 Full Name Where is your hometown? (City, Country)  \
# 0               Joy Huang                           Xiamen, China
# 1             Yichen Zhao                         Shanghai, China
# 2             Johnny Chau                               Hong Kong
# 3                Ben Chen                                  Taiwan
# 4          Matt Marwedel                                Iowa, USA
# 5             Tzu-An Wang                         Taoyuan, Taiwan
# 6                  Max Ma                            Linyi, China
# 7            Deepak Singh                         Gurugram, India
# 8          Vichitra Kumar                            Delhi, India
# 9           Joren Libunao                        Los Angeles, USA
# 10              Shan Wang                      Qinhuangdao, China
# 11         Javier Pacheco                         Sacramento, USA
# 12   Prithvi Nuthanakalva                        Hyderabad, India
# ...

# %%
df['What is your favorite color?'] = [s.lower() for s in df['What is your favorite color?']]
df['What is your favorite color?'][11] = 'purple'
# Out:
# /var/folders/hj/tfwdfqxx77qf5hd3j44tmf2c0000gn/T/ipykernel_32054/3892318250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['What is your favorite color?'][11] = 'purple'

# %%
df['What is your favorite color?'].unique()
# Out:
# array(['emerald', 'light purple', 'navy', 'black&pink', 'blue', 'black',
#        'green', 'olive green', 'purple ', 'purple', 'white', 'pink',
#        'orange', 'aquamarine', 'red', 'yellow'], dtype=object)

# %%
def color_code(s):
    c = ''
    if s == 'red':
        c = '#e01212'
    elif s == 'blue':
        c = '#0d48d4'
    elif s == 'green':
        c = '#41851c'
    elif s == 'emerald':
        c = 'rgb(95, 251, 23)'
    elif s == 'light purple':
        c = 'rgb(167, 140, 189)'
    elif s == 'navy':
        c = '#000080'
    elif s == 'black&pink':
        c = '#000000'
    elif s == 'black':
        c = '#000000'
    elif s == 'olive green':
        c = 'rgb(128, 128, 0)'
    elif s == 'purple':
        c = '#800080'
    elif s == 'white':
        c = '#f2f2e6'
    elif s == 'pink':
        c = '#FFC0CB'
    elif s == 'orange':
        c = '#FFA500'
    elif s == 'aquamarine':
        c = '#7FFFD4'
    elif s == 'yellow':
        c = '#FFFF00'
    return c

# %%
df['color'] = [color_code(s) for s in df['What is your favorite color?']]
df
# Out:
#                 Full Name Where is your hometown? (City, Country)  \
# 0               Joy Huang                           Xiamen, China
# 1             Yichen Zhao                         Shanghai, China
# 2             Johnny Chau                               Hong Kong
# 3                Ben Chen                                  Taiwan
# 4          Matt Marwedel                                Iowa, USA
# 5             Tzu-An Wang                         Taoyuan, Taiwan
# 6                  Max Ma                            Linyi, China
# 7            Deepak Singh                         Gurugram, India
# 8          Vichitra Kumar                            Delhi, India
# 9           Joren Libunao                        Los Angeles, USA
# 10              Shan Wang                      Qinhuangdao, China
# 11         Javier Pacheco                         Sacramento, USA
# 12   Prithvi Nuthanakalva                        Hyderabad, India
# ...

# %%
names = []
for name in df['Full Name']:
    names.append(', '.join([name.split()[1],name.split()[0]]))
names
# Out:
# ['Huang, Joy',
#  'Zhao, Yichen',
#  'Chau, Johnny',
#  'Chen, Ben',
#  'Marwedel, Matt',
#  'Wang, Tzu-An',
#  'Ma, Max',
#  'Singh, Deepak',
#  'Kumar, Vichitra',
#  'Libunao, Joren',
#  'Wang, Shan',
#  'Pacheco, Javier',
#  'Nuthanakalva, Prithvi',
#  'Gupta, Ankit',
#  'Wang, Jessica',
#  'Li, Chenxi',
#  'Chiu, Annie',
#  'Jain, Anirav',
#  'Su, Lanting',
#  'Wheeler, Matt',
#  'Marepalli, Renuka',
#  'Zhang, Youshi',
#  'Gopi, Akhil',
#  'Jauregu, Patricia',
#  'Carroll, Cody',
#  'Yang, Kevin',
#  'Vannur, Lingraj',
#  'Chan, Justin',
#  'Martinez-Tobon, Andres',
#  'Nguyen, Nhi',
#  'Dasari, Tejaswi',
#  'Schwartz, Aydin',
#  'Sun, Jinwei',
#  'Chaves, Camilo',
#  'Wang, Wei',
#  'Wang, Yu-Hsin',
#  'Soni, Ity']

# %%
df['last_first'] = names
df
# Out:
#                 Full Name Where is your hometown? (City, Country)  \
# 0               Joy Huang                           Xiamen, China
# 1             Yichen Zhao                         Shanghai, China
# 2             Johnny Chau                               Hong Kong
# 3                Ben Chen                                  Taiwan
# 4          Matt Marwedel                                Iowa, USA
# 5             Tzu-An Wang                         Taoyuan, Taiwan
# 6                  Max Ma                            Linyi, China
# 7            Deepak Singh                         Gurugram, India
# 8          Vichitra Kumar                            Delhi, India
# 9           Joren Libunao                        Los Angeles, USA
# 10              Shan Wang                      Qinhuangdao, China
# 11         Javier Pacheco                         Sacramento, USA
# 12   Prithvi Nuthanakalva                        Hyderabad, India
# ...

# %%
df.sort_values(by=['last_first'], inplace=True)
df = df.reset_index()
df.drop(columns=['index'], inplace=True)
df
# Out:
#                 Full Name Where is your hometown? (City, Country)  \
# 0            Cody Carroll                           Austin, Texas
# 1             Justin Chan                          Cupertino, USA
# 2             Johnny Chau                               Hong Kong
# 3           Camilo Chaves                                  Bogota
# 4                Ben Chen                                  Taiwan
# 5              Annie Chiu                          Taipei, Taiwan
# 6          Tejaswi Dasari                         Warangal, India
# 7              Akhil Gopi                        Hyderabad, India
# 8             Ankit Gupta                           Delhi, India
# 9               Joy Huang                           Xiamen, China
# 10            Anirav Jain                        Bangalore, India
# 11       Patricia Jauregu                           Richmond, USA
# 12         Vichitra Kumar                            Delhi, India
# ...

# %%
df['id'] = range(1, len(df)+1)
df
# Out:
#                 Full Name Where is your hometown? (City, Country)  \
# 0            Cody Carroll                           Austin, Texas
# 1             Justin Chan                          Cupertino, USA
# 2             Johnny Chau                               Hong Kong
# 3           Camilo Chaves                                  Bogota
# 4                Ben Chen                                  Taiwan
# 5              Annie Chiu                          Taipei, Taiwan
# 6          Tejaswi Dasari                         Warangal, India
# 7              Akhil Gopi                        Hyderabad, India
# 8             Ankit Gupta                           Delhi, India
# 9               Joy Huang                           Xiamen, China
# 10            Anirav Jain                        Bangalore, India
# 11       Patricia Jauregu                           Richmond, USA
# 12         Vichitra Kumar                            Delhi, India
# ...

# %%
ids = df['id'].to_list()
metadata = []
for i in range(len(df)):
    metadata.append({'id': ids[i], 'name': df['last_first'][i],
                      'hometown': df['Where is your hometown? (City, Country)'][i],
                     'pet': df['Do you have any pet(s)?'][i],
                     'morning/night':df['Are you a morning or night person?'][i],
                    'favorite color': df['What is your favorite color?'][i]})
metadata
# Out:
# [{'id': 1,
#   'name': 'Carroll, Cody',
#   'hometown': 'Austin, Texas',
#   'pet': 'Yes',
#   'morning/night': 'Night',
#   'favorite color': 'orange'},
#  {'id': 2,
#   'name': 'Chan, Justin',
#   'hometown': 'Cupertino, USA',
#   'pet': 'Yes',
#   'morning/night': 'Night',
#   'favorite color': 'yellow'},
#  {'id': 3,
#   'name': 'Chau, Johnny',
#   'hometown': 'Hong Kong',
#   'pet': 'No',
#   'morning/night': 'Night',
#   'favorite color': 'navy'},
#  {'id': 4,
#   'name': 'Chaves, Camilo',
#   'hometown': 'Bogota',
#   'pet': 'No',
#   'morning/night': 'Morning',
#   'favorite color': 'yellow'},
#  {'id': 5,
#   'name': 'Chen, Ben',
#   'hometown': 'Taiwan',
#   'pet': 'Yes',
#   'morning/night': 'Night',
#   'favorite color': 'black&pink'},
#  {'id': 6,
#   'name': 'Chiu, Annie',
#   'hometown': 'Taipei, Taiwan',
#   'pet': 'No',
#   'morning/night': 'Night',
#   'favorite color': 'black'},
#  {'id': 7,
#   'name': 'Dasari, Tejaswi',
#   'hometown': 'Warangal, India',
# ...

# %%
food = []
for i in range(len(df)):
    food.append({'id': ids[i], 
                 'fav_dishes': df['Please rank 5 of your favorite dishes.'][i].split(',')})
for f in food:
    f['fav_dishes'] = [t.strip().lower() for t in f['fav_dishes']]
food
# Out:
# [{'id': 1,
#   'fav_dishes': ['sushi', 'falafel', 'pad see ew', 'pizza', 'burrito']},
#  {'id': 2,
#   'fav_dishes': ['pasta', 'ramen', 'burritos', 'fried chicken', 'curry']},
#  {'id': 3,
#   'fav_dishes': ['salmon', 'curry', 'burger', 'fried noodles', 'pizza']},
#  {'id': 4,
#   'fav_dishes': ['pizza', 'burgers', 'ice cream', 'chicken tikka', 'bread']},
#  {'id': 5,
#   'fav_dishes': ['ramen', 'sushi', 'egg fried rice', 'poké', 'chawmien.']},
#  {'id': 6,
#   'fav_dishes': ['braised pork rice', 'sushi', 'pasta', 'pizza', 'pho']},
#  {'id': 7, 'fav_dishes': ['mutton', 'chicken', 'biryani', 'dosa', 'poori.']},
#  {'id': 8,
#   'fav_dishes': ['dosa',
#    'sambar',
#    'tomato soup',
#    'avocado toast',
#    'tomato curry']},
#  {'id': 9,
#   'fav_dishes': ['butter chicken',
#    'pav bhaji',
#    'rajma rice',
#    'kadhi rice',
#    'sarson ka saag']},
#  {'id': 10,
#   'fav_dishes': ['lasagna',
#    'redvelvet cupcake',
#    'mango sticky rice',
#    'sate noodles',
# ...

# %%
exercise = []
for i in range(len(df)):
    exercise.append({'id': ids[i], 'freq': df['How many times do you exercise per week?'][i]})
exercise
# Out:
# [{'id': 1, 'freq': 4.0},
#  {'id': 2, 'freq': 1.5},
#  {'id': 3, 'freq': 3.0},
#  {'id': 4, 'freq': 3.0},
#  {'id': 5, 'freq': 2.0},
#  {'id': 6, 'freq': 0.0},
#  {'id': 7, 'freq': 3.0},
#  {'id': 8, 'freq': 4.0},
#  {'id': 9, 'freq': 2.0},
#  {'id': 10, 'freq': 2.0},
#  {'id': 11, 'freq': 5.0},
#  {'id': 12, 'freq': 3.0},
#  {'id': 13, 'freq': 3.0},
#  {'id': 14, 'freq': 0.0},
#  {'id': 15, 'freq': 3.0},
#  {'id': 16, 'freq': 2.0},
#  {'id': 17, 'freq': 1.0},
#  {'id': 18, 'freq': 0.0},
#  {'id': 19, 'freq': 4.0},
#  {'id': 20, 'freq': 4.0},
#  {'id': 21, 'freq': 2.0},
#  {'id': 22, 'freq': 2.0},
#  {'id': 23, 'freq': 6.0},
#  {'id': 24, 'freq': 2.0},
#  {'id': 25, 'freq': 0.0},
#  {'id': 26, 'freq': 1.0},
#  {'id': 27, 'freq': 3.0},
#  {'id': 28, 'freq': 3.0},
#  {'id': 29, 'freq': 0.0},
#  {'id': 30, 'freq': 0.0},
#  {'id': 31, 'freq': 1.0},
#  {'id': 32, 'freq': 1.0},
#  {'id': 33, 'freq': 1.0},
#  {'id': 34, 'freq': 3.0},
#  {'id': 35, 'freq': 2.0},
#  {'id': 36, 'freq': 0.0},
# ...

# %%
survey = {'ids': ids, 'metadata': metadata, 'food': food, 'exercise': exercise}
with open('survey.json', 'w') as f:
    json.dump(survey, f)
